# %%
from google import genai
from google.genai import types
from dotenv import load_dotenv
import os
import requests


load_dotenv()
api_key = os.getenv("GEMINI_API_KEY")


image_path = "https://images.unsplash.com/photo-1775315815915-43af175d4c95?q=80&w=2070&auto=format&fit=crop&ixlib=rb-4.1.0&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D"
image_bytes = requests.get(image_path).content
image = types.Part.from_bytes(
    data=image_bytes, mime_type="image/jpeg"
)

client = genai.Client(api_key=api_key)
contents = [
    "이 이미지에 대해 설명해 주세요.", image
]

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=contents
)

response.text
# Out:
# '이 이미지는 비 오는 밤 도시 거리의 활기찬 풍경을 담고 있습니다.\n\n사진의 전경에는 넓은 횡단보도가 보이며, 비에 젖어 반짝이는 아스팔트가 거리의 조명과 네온사인들을 황금빛, 주황빛, 초록빛으로 반사하고 있습니다. 수많은 보행자들이 횡단보도를 건너고 있으며, 대부분은 비를 피하기 위해 우산을 들고 있습니다. 사람들은 움직임 때문에 흐릿하게 표현되어 실루엣처럼 보이며, 이는 바쁜 도시의 역동성을 강조합니다.\n\n배경에는 밝게 빛나는 건물들이 눈에 띕니다. 오른쪽에는 "薬 (약)"과 "コクミンドラッグ" (코쿠민 드럭)이라는 일본어 간판이 선명한 약국 또는 편의점이 밝게 빛나고 있습니다. 가게 내부의 진열된 상품들이 환하게 보이며, 그 위에는 "免税店 (면세점)"과 "薬妝店 (약장점, 즉 드럭스토어)"이라는 간판도 보입니다. 왼쪽에는 "洋服の青山 (요후쿠노 아오야마)"라는 이름의 정장 판매점으로 보이는 세로형 파란색 네온 간판이 있는 고층 건물이 서 있습니다.\n\n전체적으로 이미지는 젖은 아스팔트의 반사와 사람들의 움직임으로 인해 역동적이면서도 몽환적인 분위기를 자아냅니다. 도시의 불빛과 비 내리는 밤이 어우러져 고요하면서도 활기찬 동아시아 도시의 밤 풍경을 아름답게 포착하고 있습니다.'

# %%
with open('./image/image.jpg', 'rb') as f:
    image_bytes = f.read()

response = client.models.generate_content(
    model='gemini-2.5-flash',
    contents = [
        types.Part.from_bytes(
            data=image_bytes,
            mime_type='image/jpeg'
        ),
        '이 이미지에 대해 설명해주세요.'
    ]
)

response.text
# Out:
# "이 이미지는 주방 조리대 위에서 한국식 고기 요리를 준비하는 모습을 담고 있습니다.\n\n화면 중앙에는 두 개의 투명한 쟁반에 신선한 소고기 여러 덩이가 가지런히 놓여 있습니다. 고기는 키친타월 위에 올려져 있어 핏물을 제거하고 있는 것으로 보입니다.\n*   왼쪽 쟁반에는 마블링이 좋은 두툼한 스테이크용 소고기가 세 덩이 놓여 있으며, 육즙이 촉촉하게 보입니다.\n*   오른쪽 쟁반에는 좀 더 얇고 길게 손질된 갈비나 차돌박이 같은 부위의 소고기가 여러 덩이 놓여 있습니다. 이 고기들 역시 신선해 보입니다.\n\n고기들 위로는 두 개의 작은 흰색 사각 그릇에 빨간색 양념(쌈장 또는 고추장 양념)이 담겨 있습니다. 양념은 고추장 베이스에 다진 마늘이나 깨 등의 재료가 섞인 것으로 보이며, 오른쪽 양념 그릇에는 작은 숟가락이 꽂혀 있습니다.\n\n그 뒤로는 흰색 뚜껑이 있는 투명한 밀폐 용기가 보이며, 안에는 주황색 또는 붉은색 액체가 담겨 있습니다. 이는 고기 양념이나 다른 소스, 또는 김치 국물 등일 수 있습니다.\n\n배경으로는 베이지색과 갈색이 섞인 대리석 무늬의 주방 조리대가 펼쳐져 있습니다.\n*   왼쪽 상단에는 '숨'이라는 글자가 적힌 노란색 비닐 포장(음식 관련 제품으로 추정)과 꽃무늬(핑크색 장미와 파란색 리본)가 그려진 흰색 도자기 수저통이 보이며, 그 안에는 다양한 종류의 숟가락과 젓가락이 꽂혀 있습니다.\n*   오른쪽 상단에는 나무로 된 주방용품(칼꽂이 등으로 추정)의 일부가 보입니다.\n\n전반적으로 식사를 위한 고기 준비가 한창인 활기찬 분위기를 느낄 수 있습니다."

# %%
with open("./image/gram.jpg", "rb") as f:
    image_bytes1 = f.read()
with open("./image/galaxybook.jpg", "rb") as f:
    image_bytes2 = f.read()

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=[
        types.Part.from_bytes(
            data=image_bytes1, mime_type='image/jpeg'
        ),
        types.Part.from_bytes(
            data=image_bytes2, mime_type='image/jpeg'
        ),
        '이 두 이미지의 차이점이 뭔지 설명해줘.'
    ]
)

response.text
# Out:
# ---------------------------------------------------------------------------
# ServerError                               Traceback (most recent call last)
# Cell In[6], line 6
#       2     image_bytes1 = f.read()
#       3 with open("./image/galaxybook.jpg", "rb") as f:
#       4     image_bytes2 = f.read()
#       5
# ----> 6 response = client.models.generate_content(
#       7     model="gemini-2.5-flash",
#       8     contents=[
#       9         types.Part.from_bytes(
#
# File c:\Users\hoyon\OneDrive\바탕 화면\Develope\InProgress\LLM_AI_Agent\remind\Chap06\venv\Lib\site-packages\google\genai\models.py:6021, in Models.generate_content(self, model, contents, config)
#    6019 while remaining_remote_calls_afc > 0:
#    6020   i += 1
# -> 6021   response = self._generate_content(
#    6022       model=model, contents=contents, config=parsed_config
#    6023   )
#    6025   function_map = _extra_utils.get_function_map(parsed_config)
#    6026   if not function_map:
#
# ...
