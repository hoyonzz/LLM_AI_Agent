# %%
from openai import OpenAI
from dotenv import load_dotenv
import os


load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")

client = OpenAI(api_key=api_key)

messages = [
    {
        "role" : "user",
        "content" : [
            {"type" : "text", "text": "이 이미지에 대해 설명해 주세요."},
            {
                "type": "image_url",
                "image_url": {"url" : "https://images.unsplash.com/photo-1775315815915-43af175d4c95?q=80&w=2070&auto=format&fit=crop&ixlib=rb-4.1.0&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D",},
            },
        ],
    }
]

response = client.chat.completions.create(
    model='gpt-4o',
    messages=messages
)

response

# %%
import base64


def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode("utf-8")
    
image_path = "./image/image.jpg"

base64_image = encode_image(image_path)

print(base64_image)

# %%
messages = [
    {
        "role" : "user",
        "content" : [
            {"type":"text", "text": "이 이미지에 대해 설명해주세요."},
            {
                "type": "image_url",
                "image_url" : {
                    "url": f"...{base64_image}",
                },
            },
        ],
    }
]

response = client.chat.completions.create(
    model = "gpt-4o",
    messages=messages
)

response.choices[0].message.content

# %%
gram_base64 = encode_image("./image/gram.jpg")
galaxybook_base64 = encode_image("./image/galaxybook.jpg")

messages = [
    {
        "role" : "user",
        "content" : [
            {
                "type" : "text", "text" : "두 노트북의 차이점을 설명해주세요."
            },
            {
                "type" : "image_url",
                "image_url": {
                    "url" : f"data:image/jpg;base64,{gram_base64}",
                },
            },
            {
                "type" : "image_url",
                "image_url" : {
                    "url" : f"data:image/jpg;base64,{galaxybook_base64}"
                },
            },
        ],
    }
]

response = client.chat.completions.create(
    model = 'gpt-4o',
    messages=messages
)

response.choices[0].message.content
# Out:
# "두 노트북의 차이점을 이미지로만 파악할 수 있는 부분은 디자인적 요소입니다. \n\n1. **브랜드와 디자인**\n   - 첫 번째 노트북은 LG 브랜드로, 'gram' 로고가 후면에 새겨져 있으며 깔끔한 메탈릭 디자인을 가지고 있습니다.\n   - 두 번째 노트북은 삼성 브랜드로, 커버에 'SAMSUNG' 로고가 있으며 역시 미니멀한 디자인을 특징으로 합니다.\n\n2. **키보드와 터치패드 배열**\n   - 첫 번째 노트북은 키보드 배열이 중앙에 위치하며 터치패드가 넓직하게 배치되어 있습니다.\n   - 두 번째 노트북도 비슷하게 배열되어 있지만, 키보드 디자인에 약간 차이가 있을 수 있습니다.\n\n3. **컬러**\n   - 첫 번째 노트북은 실버 색상의 메탈릭 느낌을 주며,\n   - 두 번째 노트북은 짙은 그레이 색상입니다.\n\n추가적인 요소들(성능, 규격, 기능 등)은 이미지만으로는 알 수 없으니 각 제품의 상세 사양을 확인해야 합니다."

# %%
oecd_rnd_2021_base64 = encode_image("./image/oecd_rnd_2021_large.png")
oecd_rnd_2022_base64 = encode_image("./image/oecd_rnd_2022.png")

messages = [
    {
        "role" : "user",
        "content" : [
            {
                "type" : "text", "text" : "첫 번째는 2021년 데이터이고, 두 번째는 2022년 데이터입니다. 이 데이터에 대해 설명해주세요. 어떤 변화가 있었나요? 한국을 중심으로 설명해주세요."
            },
            {
                "type" : "image_url",
                "image_url" : {
                    "url" : f"data:image/jpeg;base64,{oecd_rnd_2021_base64}",
                },
            },
            {
                "type" : "image_url",
                "image_url" : {
                    "url" : f"data:image/jpeg;base64,{oecd_rnd_2022_base64}",
                },
            },
        ],
    }
]

response = client.chat.completions.create(
    model = 'gpt-4o',
    messages=messages
)

response.choices[0].message.content
# Out:
# '이 두 데이터는 2021년과 2022년의 국가별 연구개발비(R&D)와 GDP 대비 연구개발비 비중을 보여줍니다.\n\n한국을 중심으로 비교해보면:\n\n1. **연구개발비 증가**:\n   - 2021년: 한국의 연구개발비는 약 89,282백만 달러였으며,\n   - 2022년: 약 91,013백만 달러로 증가했습니다.\n\n2. **GDP 대비 연구개발비 비중**:\n   - 2021년: 4.93%\n   - 2022년: 5.21%\n   \n한국의 연구개발비와 GDP 대비 비중 모두 증가했습니다. 이는 한국이 연구개발에 더 많은 자원을 투입하고 있으며, 경제 규모 대비 연구개발 투자 비중도 높아졌다는 것을 나타냅니다.\n\n다른 국가들과 비교했을 때, 한국은 여전히 높은 연구개발비 비중을 유지하고 있으며, 글로벌 연구개발 경쟁에서 중요한 위치를 차지하고 있습니다.'

# %%
oecd_rnd_2021_base64 = encode_image("./image/oecd_rnd_2021_medium.png")
oecd_rnd_2022_base64 = encode_image("./image/oecd_rnd_2022.png")

messages = [
    {
        "role" : "user",
        "content" : [
            {
                "type" : "text", "text" : "첫 번째는 2021년 데이터이고, 두 번째는 2022년 데이터입니다. 이 데이터에 대해 설명해주세요. 어떤 변화가 있었나요? 한국을 중심으로 설명해주세요."
            },
            {
                "type" : "image_url",
                "image_url" : {
                    "url" : f"data:image/jpeg;base64,{oecd_rnd_2021_base64}",
                },
            },
            {
                "type" : "image_url",
                "image_url" : {
                    "url" : f"data:image/jpeg;base64,{oecd_rnd_2022_base64}",
                },
            },
        ],
    }
]

response = client.chat.completions.create(
    model = 'gpt-4o',
    messages=messages
)

response.choices[0].message.content
# Out:
# '두 이미지에서 한국의 연구개발비와 GDP 대비 연구개발비 비중을 중심으로 살펴보겠습니다.\n\n### 2021년 데이터:\n- **연구개발비**: 121,739백만 달러\n- **GDP 대비 연구개발비 비중**: 4.93%\n\n### 2022년 데이터:\n- **연구개발비**: 87,225백만 달러\n- **GDP 대비 연구개발비 비중**: 4.93%\n\n### 변화 분석:\n1. **연구개발비 감소**: 2021년에서 2022년으로 연구개발비가 121,739백만 달러에서 87,225백만 달러로 감소했습니다.\n2. **GDP 대비 연구개발비 비중 유지**: 비중은 두 해 모두 4.93%로 동일하게 유지되었습니다.\n\n### 요약:\n한국은 연구개발비 규모가 감소했지만, GDP 대비 연구개발비 비중은 그대로 유지되었습니다. 이는 경제 규모의 변화나 특정 연구개발 비용의 조정이 있었을 가능성을 시사합니다. 다른 나라와 비교했을 때 여전히 높은 비중을 유지하고 있습니다.'
