# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")
client = OpenAI(api_key=api_key)

# %%
response = client.audio.speech.create(
    model='tts-1-hd',
    voice='alloy',
    input="Hello world! This is a TTS test.",
)

response.write_to_file("hello_world.mp3")

import IPython.display as ipd

ipd.Audio("hello_world.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
voice = "ash"
mp3_file = f"hello_world_{voice}.mp3"

response = client.audio.speech.create(
    model='tts-1-hd',
    voice=voice,
    input=f"Hello world! I'm {voice}. This is a TTS test."
)

response.write_to_file(mp3_file)

import IPython.display as ipd

ipd.Audio(mp3_file)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import json

with open('image/quiz/image_quiz_eng.json', 'r', encoding='utf-8') as f:
    eng_dict = json.load(f)

eng_dict
# Out:
# [{'no': 1,
#   'eng': 'Which of the following descriptions of the image is incorrect?\n- (1) People are sitting in front of computers.\n- (2) The ceiling lights are on.\n- (3) There is a banner on the wall with the text "DIVE 2024 in BUSAN."\n- (4) People are watching a sports game.',
#   'img': 'busan_dive.jpg'},
#  {'no': 2,
#   'eng': 'Which of the following descriptions of the image is incorrect?\n- (1) There is a logo on the top cover of the laptop.\n- (2) The keyboard includes a number pad.\n- (3) The display is turned off.\n- (4) The color of the laptop is gray.',
#   'img': 'galaxybook.jpg'},
#  {'no': 3,
#   'eng': 'Which of the following descriptions of the image is incorrect?\n- (1) There are two laptops in the image.\n- (2) One of the laptops has its screen open.\n- (3) The brand name on the laptop is displayed as "Samsung."\n- (4) The background of the image is dark-colored.',
#   'img': 'gram.jpg'},
#  {'no': 4,
#   'eng': 'Which of the following descriptions of the image is incorrect?\n- (1) Pieces of meat are placed on the table.\n- (2) There are sauces in two small dishes.\n- (3) There is a floral-patterned cup in the upper left corner.\n- (4) The container has a transparent lid.',
#   'img': 'image.jpg'},
#  {'no': 5,
#   'eng': 'Which of the following descriptions of the image is incorrect?\n\n- (1) A large yellow sculpture is visible.\n- (2) The words "Local Stitch" are on the building.\n- (3) There is a brick building in the image.\n- (4) There are people lined up in the image.',
#   'img': 'local_stitch.jpg'}]

# %%
voices = ['alloy', 'ash', 'coral', 'echo', 'fable', 'onyx', 'nova', 'sage', 'shimmer']

for q in eng_dict:
    no = q['no']
    quiz = q['eng']
    quiz = quiz.replace("- (1)", "- One.\t")
    quiz = quiz.replace("- (2)", "- Two.\t")
    quiz = quiz.replace("- (3)", "- Three.\t")
    quiz = quiz.replace("- (4)", "- Four.\t")

    print(no, quiz)

    voice = voices[no % len(voices)]

    response = client.audio.speech.create(
        model='tts-1-hd',
        voice=voice,
        input=f'#{no}. {quiz}',
    )

    response.write_to_file(f"image/quiz/{no}.mp3")
# Out:
# 1 Which of the following descriptions of the image is incorrect?
# - One.	 People are sitting in front of computers.
# - Two.	 The ceiling lights are on.
# - Three.	 There is a banner on the wall with the text "DIVE 2024 in BUSAN."
# - Four.	 People are watching a sports game.
# 2 Which of the following descriptions of the image is incorrect?
# - One.	 There is a logo on the top cover of the laptop.
# - Two.	 The keyboard includes a number pad.
# - Three.	 The display is turned off.
# - Four.	 The color of the laptop is gray.
# 3 Which of the following descriptions of the image is incorrect?
# - One.	 There are two laptops in the image.
# - Two.	 One of the laptops has its screen open.
# - Three.	 The brand name on the laptop is displayed as "Samsung."
# - Four.	 The background of the image is dark-colored.
# 4 Which of the following descriptions of the image is incorrect?
# - One.	 Pieces of meat are placed on the table.
# - Two.	 There are sauces in two small dishes.
# - Three.	 There is a floral-patterned cup in the upper left corner.
# - Four.	 The container has a transparent lid.
# 5 Which of the following descriptions of the image is incorrect?
#
# - One.	 A large yellow sculpture is visible.
# - Two.	 The words "Local Stitch" are on the building.
# - Three.	 There is a brick building in the image.
# - Four.	 There are people lined up in the image.
