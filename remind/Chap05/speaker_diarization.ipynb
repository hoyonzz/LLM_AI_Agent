# %%
# %pip install pyannote.audio
# %pip install numpy

# %%
# instantiate the pipeline
from google.colab import userdata
import torch
from pyannote.audio import Pipeline
HUGGING_FACE_TOKEN = userdata.get("HUGGING_FACE_TOKEN")
pipeline = Pipeline.from_pretrained("pyannote/speaker-diarization-3.1",
  token=HUGGING_FACE_TOKEN)

if torch.cuda.is_available():
  pipeline.to(torch.device("cuda"))
  print('cuda is available')
else:
  print('cuda is not available')
# Out:
# cuda is available

# %%
# !ffmpeg -y -i "/content/sample_data/싼기타_비싼기타.mp3" -ar 16000 -ac 1 "/content/sample_data/싼기타_비싼기타.wav"
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
diarization = pipeline("/content/sample_data/싼기타_비싼기타.wav")

with open("/content/sample_data/싼기타_비싼기타.rttm", "w", encoding='utf-8') as rttm:
  diarization.speaker_diarization.write_rttm(rttm)

# %%
import pandas as pd
rttm_path = "/content/sample_data/싼기타_비싼기타.rttm"

df_rttm = pd.read_csv(
    rttm_path,
    sep=' ',
    header=None,
    names=['type', 'file', 'chnl', 'start', 'duration', 'C1', 'C2', 'speaker_id', 'C3', 'C4']
)

display(df_rttm)
# Out:
#        type      file  chnl    start  duration  C1  C2  speaker_id  C3  C4
# 0   SPEAKER  싼기타_비싼기타     1    0.993     5.805 NaN NaN  SPEAKER_01 NaN NaN
# 1   SPEAKER  싼기타_비싼기타     1    7.405     3.949 NaN NaN  SPEAKER_01 NaN NaN
# 2   SPEAKER  싼기타_비싼기타     1   11.759     4.911 NaN NaN  SPEAKER_01 NaN NaN
# 3   SPEAKER  싼기타_비싼기타     1   17.227    10.648 NaN NaN  SPEAKER_01 NaN NaN
# 4   SPEAKER  싼기타_비싼기타     1   28.668     1.519 NaN NaN  SPEAKER_01 NaN NaN
# ..      ...       ...   ...      ...       ...  ..  ..         ...  ..  ..
# 83  SPEAKER  싼기타_비싼기타     1  414.481     2.970 NaN NaN  SPEAKER_00 NaN NaN
# 84  SPEAKER  싼기타_비싼기타     1  417.755     3.476 NaN NaN  SPEAKER_01 NaN NaN
# 85  SPEAKER  싼기타_비싼기타     1  423.644     0.793 NaN NaN  SPEAKER_00 NaN NaN
# 86  SPEAKER  싼기타_비싼기타     1  424.741     3.544 NaN NaN  SPEAKER_00 NaN NaN
# 87  SPEAKER  싼기타_비싼기타     1  428.487     0.861 NaN NaN  SPEAKER_00 NaN NaN
#
# [88 rows x 10 columns]

# %%
df_rttm['end'] = df_rttm['start'] + df_rttm['duration']

display(df_rttm)
# Out:
#        type      file  chnl    start  duration  C1  C2  speaker_id  C3  C4  \
# 0   SPEAKER  싼기타_비싼기타     1    0.993     5.805 NaN NaN  SPEAKER_01 NaN NaN
# 1   SPEAKER  싼기타_비싼기타     1    7.405     3.949 NaN NaN  SPEAKER_01 NaN NaN
# 2   SPEAKER  싼기타_비싼기타     1   11.759     4.911 NaN NaN  SPEAKER_01 NaN NaN
# 3   SPEAKER  싼기타_비싼기타     1   17.227    10.648 NaN NaN  SPEAKER_01 NaN NaN
# 4   SPEAKER  싼기타_비싼기타     1   28.668     1.519 NaN NaN  SPEAKER_01 NaN NaN
# ..      ...       ...   ...      ...       ...  ..  ..         ...  ..  ..
# 83  SPEAKER  싼기타_비싼기타     1  414.481     2.970 NaN NaN  SPEAKER_00 NaN NaN
# 84  SPEAKER  싼기타_비싼기타     1  417.755     3.476 NaN NaN  SPEAKER_01 NaN NaN
# 85  SPEAKER  싼기타_비싼기타     1  423.644     0.793 NaN NaN  SPEAKER_00 NaN NaN
# 86  SPEAKER  싼기타_비싼기타     1  424.741     3.544 NaN NaN  SPEAKER_00 NaN NaN
# 87  SPEAKER  싼기타_비싼기타     1  428.487     0.861 NaN NaN  SPEAKER_00 NaN NaN
#
#         end
# 0     6.798
# 1    11.354
# 2    16.670
# 3    27.875
# ...

# %%
df_rttm["number"] = None
df_rttm.at[0, "number"] = 0

display(df_rttm)
# Out:
#        type      file  chnl    start  duration  C1  C2  speaker_id  C3  C4  \
# 0   SPEAKER  싼기타_비싼기타     1    0.993     5.805 NaN NaN  SPEAKER_01 NaN NaN
# 1   SPEAKER  싼기타_비싼기타     1    7.405     3.949 NaN NaN  SPEAKER_01 NaN NaN
# 2   SPEAKER  싼기타_비싼기타     1   11.759     4.911 NaN NaN  SPEAKER_01 NaN NaN
# 3   SPEAKER  싼기타_비싼기타     1   17.227    10.648 NaN NaN  SPEAKER_01 NaN NaN
# 4   SPEAKER  싼기타_비싼기타     1   28.668     1.519 NaN NaN  SPEAKER_01 NaN NaN
# ..      ...       ...   ...      ...       ...  ..  ..         ...  ..  ..
# 83  SPEAKER  싼기타_비싼기타     1  414.481     2.970 NaN NaN  SPEAKER_00 NaN NaN
# 84  SPEAKER  싼기타_비싼기타     1  417.755     3.476 NaN NaN  SPEAKER_01 NaN NaN
# 85  SPEAKER  싼기타_비싼기타     1  423.644     0.793 NaN NaN  SPEAKER_00 NaN NaN
# 86  SPEAKER  싼기타_비싼기타     1  424.741     3.544 NaN NaN  SPEAKER_00 NaN NaN
# 87  SPEAKER  싼기타_비싼기타     1  428.487     0.861 NaN NaN  SPEAKER_00 NaN NaN
#
#         end number
# 0     6.798      0
# 1    11.354   None
# ...

# %%
for i in range(1, len(df_rttm)):
  if df_rttm.at[i, "speaker_id"] != df_rttm.at[i-1, "speaker_id"]:
    df_rttm.at[i, "number"] = df_rttm.at[i-1, "number"] + 1
  else:
    df_rttm.at[i, "number"] = df_rttm.at[i-1, "number"]
display(df_rttm.head(10))
# Out:
#       type      file  chnl   start  duration  C1  C2  speaker_id  C3  C4  \
# 0  SPEAKER  싼기타_비싼기타     1   0.993     5.805 NaN NaN  SPEAKER_01 NaN NaN
# 1  SPEAKER  싼기타_비싼기타     1   7.405     3.949 NaN NaN  SPEAKER_01 NaN NaN
# 2  SPEAKER  싼기타_비싼기타     1  11.759     4.911 NaN NaN  SPEAKER_01 NaN NaN
# 3  SPEAKER  싼기타_비싼기타     1  17.227    10.648 NaN NaN  SPEAKER_01 NaN NaN
# 4  SPEAKER  싼기타_비싼기타     1  28.668     1.519 NaN NaN  SPEAKER_01 NaN NaN
# 5  SPEAKER  싼기타_비싼기타     1  32.414     0.742 NaN NaN  SPEAKER_00 NaN NaN
# 6  SPEAKER  싼기타_비싼기타     1  33.562     3.527 NaN NaN  SPEAKER_00 NaN NaN
# 7  SPEAKER  싼기타_비싼기타     1  37.645     3.729 NaN NaN  SPEAKER_00 NaN NaN
# 8  SPEAKER  싼기타_비싼기타     1  41.628     1.080 NaN NaN  SPEAKER_00 NaN NaN
# 9  SPEAKER  싼기타_비싼기타     1  41.662     0.776 NaN NaN  SPEAKER_01 NaN NaN
#
#       end number
# 0   6.798      0
# 1  11.354      0
# 2  16.670      0
# 3  27.875      0
# 4  30.187      0
# 5  33.156      1
# 6  37.089      1
# ...

# %%
df_rttm_grouped = df_rttm.groupby("number").agg(
    start=pd.NamedAgg(column='start', aggfunc='min'),
    end=pd.NamedAgg(column='end', aggfunc='max'),
    speaker_id=pd.NamedAgg(column='speaker_id', aggfunc='first')
)

display(df_rttm_grouped)
# Out:
#           start      end  speaker_id
# number
# 0         0.993   30.187  SPEAKER_01
# 1        32.414   42.708  SPEAKER_00
# 2        41.662   44.024  SPEAKER_01
# 3        45.813   67.092  SPEAKER_00
# 4        67.227   82.769  SPEAKER_01
# 5        84.659  102.547  SPEAKER_00
# 6       103.492  117.515  SPEAKER_01
# 7       119.742  138.676  SPEAKER_00
# 8       139.351  168.967  SPEAKER_01
# 9       170.924  192.304  SPEAKER_00
# 10      192.322  193.655  SPEAKER_01
# 11      192.777  193.503  SPEAKER_00
# 12      193.891  216.571  SPEAKER_01
# 13      218.579  238.120  SPEAKER_00
# 14      238.120  238.660  SPEAKER_01
# 15      238.188  239.352  SPEAKER_00
# 16      239.858  240.651  SPEAKER_01
# 17      240.297  240.972  SPEAKER_00
# 18      241.040  251.317  SPEAKER_01
# 19      253.696  271.533  SPEAKER_00
# 20      272.140  304.557  SPEAKER_01
# 21      306.970  326.022  SPEAKER_00
# 22      326.360  335.455  SPEAKER_01
# 23      337.548  355.908  SPEAKER_00
# ...

# %%
df_rttm_grouped["duration"] = df_rttm_grouped["end"] - df_rttm_grouped["start"]
df_rttm_grouped = df_rttm_grouped.reset_index(drop=True)
display(df_rttm_grouped)
# Out:
#       start      end  speaker_id  duration
# 0     0.993   30.187  SPEAKER_01    29.194
# 1    32.414   42.708  SPEAKER_00    10.294
# 2    41.662   44.024  SPEAKER_01     2.362
# 3    45.813   67.092  SPEAKER_00    21.279
# 4    67.227   82.769  SPEAKER_01    15.542
# 5    84.659  102.547  SPEAKER_00    17.888
# 6   103.492  117.515  SPEAKER_01    14.023
# 7   119.742  138.676  SPEAKER_00    18.934
# 8   139.351  168.967  SPEAKER_01    29.616
# 9   170.924  192.304  SPEAKER_00    21.380
# 10  192.322  193.655  SPEAKER_01     1.333
# 11  192.777  193.503  SPEAKER_00     0.726
# 12  193.891  216.571  SPEAKER_01    22.680
# 13  218.579  238.120  SPEAKER_00    19.541
# 14  238.120  238.660  SPEAKER_01     0.540
# 15  238.188  239.352  SPEAKER_00     1.164
# 16  239.858  240.651  SPEAKER_01     0.793
# 17  240.297  240.972  SPEAKER_00     0.675
# 18  241.040  251.317  SPEAKER_01    10.277
# 19  253.696  271.533  SPEAKER_00    17.837
# 20  272.140  304.557  SPEAKER_01    32.417
# ...

# %%
df_rttm_grouped.to_csv(
    "/content/sample_data/싼기타_비싼기타_rttm.csv",
    sep=',',
    index=False
)
