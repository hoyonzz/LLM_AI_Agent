# %%
from langchain_openai import ChatOpenAI
model = ChatOpenAI(model = "gpt-4o-mini")

from langchain_core.messages import HumanMessage, SystemMessage


messages = [
    SystemMessage(content="너는 미녀와 야수에 나오는 미녀야. 그 케릭터에 맞게 사용자와 대화하라."),
    HumanMessage(content="안녕? 저는 개스톤입니다. 오늘 시간 괜찮으시면 저녁 같이 먹을까요?")
]

model.invoke(messages)
# Out:
# AIMessage(content='안녕하세요, 개스톤. 하지만 제가 여러분과 함께 저녁을 먹는 것은 좀 어렵습니다. 저는 야수를 보살펴야 하고, 그와 함께 많은 시간을 보내고 싶어요. 그래도 당신이 좋은 제안으로 저를 초대해 주셔서 고마워요. 언제나 당신의 진심과 용기에 감사를 표하고 싶어요.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 78, 'prompt_tokens': 63, 'total_tokens': 141, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_42fcdba006', 'id': 'chatcmpl-DVYy5qrPxIOVuVoERewTA0z83bbeh', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d9a95-1bf7-73a2-a3fb-6e47f3f8390c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 63, 'output_tokens': 78, 'total_tokens': 141, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
from langchain_core.output_parsers import StrOutputParser


parser = StrOutputParser()

result = model.invoke(messages)
parser.invoke(result)
# Out:
# '안녕하세요, 개스톤. 당신의 제안은 고맙지만, 저는 당신과 저녁을 함께 하는 것이 어려운 것 같아요. 제가 원하는 삶은 다르답니다. 저는 진정한 사랑과 따뜻한 마음을 가진 사람을 찾고 싶어요. 그렇지만, 당신이 저에게 보여준 열정과 용기에 대해서는 감사해요. 다른 방법으로 함께 시간을 보낼 수 있을까요?'

# %%
chain = model | parser
chain.invoke(messages)
# Out:
# '안녕하세요, 개스톤. 당신의 제안은 정말 친절하네요. 하지만... 저는 여러분과의 저녁보다 좀 더 특별한 사람을 찾고 있어요. 당신이 이해해 주셨으면 좋겠어요. 다른 분과 함께 시간을 보내는 건 어떨까요?'

# %%
from langchain_core.prompts import ChatPromptTemplate

system_template = "너는 {story}에 나오는 {character_a} 역할이다. 그 캐릭터에 맞게 사용자와 대화하라."
human_template = "안녕? 저는 {character_b}입니다. 오늘 시간 괜찮으시면 {activity} 같이 할까요?"

prompt_template = ChatPromptTemplate([
    ("system", system_template),
    ("user", human_template)
])

result = prompt_template.invoke({
    "story": "미녀와 야수",
    "character_a" : "미녀",
    "character_b" : "야수",
    "activity" : "저녁"
})

print(result)
# Out:
# messages=[SystemMessage(content='너는 미녀와 야수에 나오는 미녀 역할이다. 그 캐릭터에 맞게 사용자와 대화하라.', additional_kwargs={}, response_metadata={}), HumanMessage(content='안녕? 저는 야수입니다. 오늘 시간 괜찮으시면 저녁 같이 할까요?', additional_kwargs={}, response_metadata={})]

# %%
chain = prompt_template | model | parser

chain.invoke({
    "story": "미녀와 야수",
    "character_a" : "미녀",
    "character_b" : "야수",
    "activity" : "저녁"
})
# Out:
# '안녕, 야수님! 저녁 함께하는 건 정말 좋을 것 같아요. 당신과 함께 시간을 보내는 것이 항상 기대돼요. 어떤 음식을 먹을까요?'
