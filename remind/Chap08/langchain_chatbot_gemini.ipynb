# %%
from langchain_google_genai import ChatGoogleGenerativeAI


model = ChatGoogleGenerativeAI(model='gemini-2.5-flash')

# %%
from langchain_core.messages import HumanMessage
model.invoke([HumanMessage(content="안녕?난신호용이야.")])
# Out:
# AIMessage(content='안녕하세요, 신호용님! 만나서 정말 반가워요. 😊\n\n저는 신호용님과 대화하고 도움을 드릴 수 있는 인공지능 어시스턴트예요.\n\n어떤 것을 궁금해하시거나, 어떤 도움이 필요하신가요? 언제든지 말씀해주세요!', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019d9a6e-ae76-7001-98bb-28480863849a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 1031, 'total_tokens': 1041, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 968}})
