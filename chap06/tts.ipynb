# %%
from openai import OpenAI
from dotenv import load_dotenv
import os


load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")
client = OpenAI(api_key=api_key)

# %%
# TTS 함수
response = client.audio.speech.create(
    model="tts-1-hd",
    voice = "alloy",
    input = "Hello world! This is a TTS test"
)

response.write_to_file("hello_world.mp3")

# %%
voice = "echo"
mp3_file = f"hello_world_{voice}.mp3"

response = client.audio.speech.create(
    model = "tts-1-hd",
    voice = voice,
    input = f"Hello world! I'm {voice}. This is a TTS test.",
)

response.write_to_file(mp3_file)

# import Ipython.display as ipd

# ipd.Audio(mp3_file)

# %%
import json

with open('./data/images/image_quiz_eng.json', 'r', encoding='utf-8') as f:
    eng_dict = json.load(f)

eng_dict
# Out:
# [{'no': 1,
#   'eng': 'Which of the following descriptions of the image is incorrect?\n- (1) Many people are attending a seminar.\n- (2) A large screen is visible at the top of the image.\n- (3) Everyone is eating food in the conference room.\n- (4) There are lights installed in the ceiling.',
#   'img': 'busan_dive.jpg'},
#  {'no': 2,
#   'eng': 'Which of the following descriptions of the image is incorrect?\n- (1) People are sitting and chatting inside the cafe.\n- (2) A barista is working behind the counter.\n- (3) There is a yellow wall behind the counter.\n- (4) There are multiple chairs and tables set up.',
#   'img': 'local_stitch_terrarosa.jpg'},
#  {'no': 3,
#   'eng': 'Which of the following descriptions of the image is incorrect?\n- (1) There are various types of bread on display.\n- (2) The staff is wearing a white hat.\n- (3) The bread does not have price tags.\n- (4) There is a glass display case.',
#   'img': 'mangwon_bakery.jpg'},
#  {'no': 4,
#   'eng': 'Which of the following descriptions of the image is incorrect?\n- (1) Several people are sitting and conversing.\n- (2) The outside view can be seen through the windows.\n- (3) There are books piled on the table.\n- (4) Lighting fixtures are installed on the ceiling.',
#   'img': 'seolleung_terrarosa.jpg'}]

# %%
voices = ['alloy', 'ash', 'coral', 'echo', 'fable', 'onyx', 'nova', 'sage', 'shimmer']

for q in eng_dict:
    no = q['no']
    quiz = q['eng']
    quiz = quiz.replace("- (1)", "- One.\t")
    quiz = quiz.replace("- (2)", "- Two.\t")
    quiz = quiz.replace("- (3)", "- Three.\t")
    quiz = quiz.replace("- (4)", "- Four.\t")
    
    print(no, quiz)

    voice = voices[no % len(voices)]

    response = client.audio.speech.create(
        model='tts-1-hd',
        voice=voice,
        input=f'#{no}. {quiz}',
    )

    response.write_to_file(f"./data/audio/{no}.mp3")
# Out:
# 1 Which of the following descriptions of the image is incorrect?
# - One.	 Many people are attending a seminar.
# - Two.	 A large screen is visible at the top of the image.
# - Three.	 Everyone is eating food in the conference room.
# - Four.	 There are lights installed in the ceiling.
# 2 Which of the following descriptions of the image is incorrect?
# - One.	 People are sitting and chatting inside the cafe.
# - Two.	 A barista is working behind the counter.
# - Three.	 There is a yellow wall behind the counter.
# - Four.	 There are multiple chairs and tables set up.
# 3 Which of the following descriptions of the image is incorrect?
# - One.	 There are various types of bread on display.
# - Two.	 The staff is wearing a white hat.
# - Three.	 The bread does not have price tags.
# - Four.	 There is a glass display case.
# 4 Which of the following descriptions of the image is incorrect?
# - One.	 Several people are sitting and conversing.
# - Two.	 The outside view can be seen through the windows.
# - Three.	 There are books piled on the table.
# - Four.	 Lighting fixtures are installed on the ceiling.
