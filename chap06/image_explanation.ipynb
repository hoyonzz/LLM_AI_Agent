# %%
from openai import OpenAI
from dotenv import load_dotenv
import os


load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")

client = OpenAI(api_key=api_key)


messages = [
    {
        "role" : "user",
        "content" : [
            {"type" : "text", "text" : "이 이미지에 대해 설명해 주세요."},
            {
                "type" : "image_url",
                "image_url" : {
                        "url" : "https://images.unsplash.com/photo-1765692639936-e0a1ffea9b06?q=80&w=687&auto=format&fit=crop&ixlib=rb-4.1.0&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D",
                },
            },
        ],
    }
]

response = client.chat.completions.create(
    model="gpt-4o",
    messages=messages
)

response
# Out:
# ChatCompletion(id='chatcmpl-CoQcCbH4yTdOLyozInf8tdxCs6RH4', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='이 이미지는 눈이 내리는 겨울밤에 대형 크리스마스 트리의 모습입니다. 트리는 빛나는 전구와 별 장식으로 화려하게 꾸며져 있으며, 트리 꼭대기에는 빛나는 별 모양의 장식이 있습니다. 트리 아래에는 "Merry Christmas"라고 밝게 조명이 켜진 문구가 있으며, 주변에 눈이 쌓여 있어 크리스마스의 분위기를 더하고 있습니다. 배경에는 어두운 건물이 보입니다.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1766134744, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_e413f45763', usage=CompletionUsage(completion_tokens=113, prompt_tokens=1120, total_tokens=1233, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
